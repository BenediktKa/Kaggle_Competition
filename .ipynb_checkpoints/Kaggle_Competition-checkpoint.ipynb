# %% [markdown]
# # Import from Libraries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Import data

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
solution = pd.read_csv('data/sample_sol.csv', index_col=False)

# %% [markdown]
# ## Check some basic information on test data

# %%
print('Dimensions:', train.shape, '\n')
print('Types:', train.dtypes, '\n')
print('Missing Values:', train.isnull().sum(), '\n')

train.head(1000)
# Out:
# Dimensions: (13035, 12)
#
# Types: season          int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# cnt             int64
# dtype: object
#
# Missing Values: season        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# cnt           0
# dtype: int64
#      season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0         1     1   1        0        6           0           1  0.22  0.2727
# 1         1     1   2        0        6           0           1  0.22  0.2727
# 2         1     1   4        0        6           0           1  0.24  0.2879
# 3         1     1   5        0        6           0           2  0.24  0.2576
# 4         1     1   6        0        6           0           1  0.22  0.2727
# 5         1     1   7        0        6           0           1  0.20  0.2576
# 6         1     1   9        0        6           0           1  0.32  0.3485
# 7         1     1  10        0        6           0           1  0.38  0.3939
# 8         1     1  12        0        6           0           1  0.42  0.4242
# 9         1     1  13        0        6           0           2  0.46  0.4545
# 10        1     1  14        0        6           0           2  0.46  0.4545
# 11        1     1  16        0        6           0           2  0.42  0.4242
# 12        1     1  17        0        6           0           2  0.44  0.4394
# 13        1     1  18        0        6           0           3  0.42  0.4242
# 14        1     1  19        0        6           0           3  0.42  0.4242
# 15        1     1  20        0        6           0           2  0.40  0.4091
# 16        1     1  22        0        6           0           2  0.40  0.4091
# 17        1     1  23        0        6           0           2  0.46  0.4545
# 18        1     1   0        0        0           0           2  0.46  0.4545
# 19        1     1   1        0        0           0           2  0.44  0.4394
# 20        1     1   2        0        0           0           2  0.42  0.4242
# 21        1     1   4        0        0           0           2  0.46  0.4545
# 22        1     1   7        0        0           0           2  0.40  0.4091
# 23        1     1   8        0        0           0           3  0.40  0.4091
# 24        1     1   9        0        0           0           2  0.38  0.3939
# 25        1     1  10        0        0           0           2  0.36  0.3485
# 26        1     1  11        0        0           0           2  0.36  0.3333
# 27        1     1  12        0        0           0           2  0.36  0.3333
# 28        1     1  13        0        0           0           2  0.36  0.3485
# 29        1     1  15        0        0           0           3  0.34  0.3333
# ..      ...   ...  ..      ...      ...         ...         ...   ...     ...
# 970       1     2  22        0        0           0           2  0.38  0.3939
# 971       1     2  23        0        0           0           2  0.36  0.3485
# 972       1     2   0        0        1           1           2  0.36  0.3636
# 973       1     2   1        0        1           1           3  0.34  0.3030
# 974       1     2   3        0        1           1           3  0.32  0.3182
# 975       1     2   5        0        1           1           2  0.34  0.3636
# 976       1     2   6        0        1           1           2  0.34  0.3485
# 977       1     2   7        0        1           1           2  0.36  0.3636
# 978       1     2   8        0        1           1           2  0.34  0.3030
# 979       1     2   9        0        1           1           1  0.42  0.4242
# 980       1     2  12        0        1           1           2  0.56  0.5303
# 981       1     2  13        0        1           1           3  0.46  0.4545
# 982       1     2  14        0        1           1           3  0.42  0.4242
# 983       1     2  15        0        1           1           3  0.42  0.4242
# 984       1     2  16        0        1           1           3  0.42  0.4242
# 985       1     2  17        0        1           1           3  0.40  0.4091
# 986       1     2  19        0        1           1           3  0.44  0.4394
# 987       1     2  20        0        1           1           3  0.44  0.4394
# 988       1     2  21        0        1           1           2  0.38  0.3939
# 989       1     2  22        0        1           1           3  0.34  0.3030
# 990       1     2  23        0        1           1           2  0.32  0.2879
# 991       1     3   0        0        2           1           1  0.30  0.2727
# 992       1     3   2        0        2           1           1  0.24  0.2121
# 993       1     3   4        0        2           1           1  0.22  0.2121
# 994       1     3   5        0        2           1           1  0.20  0.1818
# 995       1     3   6        0        2           1           1  0.20  0.1818
# 996       1     3   7        0        2           1           1  0.20  0.1818
# 997       1     3   8        0        2           1           1  0.20  0.1818
# 998       1     3   9        0        2           1           1  0.22  0.1970
# 999       1     3  10        0        2           1           1  0.24  0.2121
#
#       hum  windspeed  cnt
# 0    0.80     0.0000   40
# 1    0.80     0.0000   32
# 2    0.75     0.0000    1
# 3    0.75     0.0896    1
# 4    0.80     0.0000    2
# 5    0.86     0.0000    3
# 6    0.76     0.0000   14
# 7    0.76     0.2537   36
# 8    0.77     0.2836   84
# 9    0.72     0.2985   94
# 10   0.72     0.2836  106
# 11   0.82     0.2985   93
# 12   0.82     0.2836   67
# 13   0.88     0.2537   35
# 14   0.88     0.2537   37
# 15   0.87     0.2537   36
# 16   0.94     0.2239   28
# 17   0.88     0.2985   39
# 18   0.88     0.2985   17
# 19   0.94     0.2537   17
# 20   1.00     0.2836    9
# 21   0.94     0.1940    3
# 22   0.76     0.1940    1
# 23   0.71     0.2239    8
# 24   0.76     0.2239   20
# 25   0.81     0.2239   53
# 26   0.71     0.2537   70
# 27   0.66     0.2985   93
# 28   0.66     0.1343   75
# 29   0.81     0.1642   74
# ..    ...        ...  ...
# 970  0.62     0.1045   69
# 971  0.62     0.1642   59
# 972  0.66     0.1045   30
# 973  0.87     0.3582    8
# 974  0.93     0.1642    1
# 975  0.93     0.0000    5
# 976  0.96     0.1045   28
# 977  0.93     0.1045   92
# 978  0.93     0.2985  255
# 979  0.82     0.2836  142
# 980  0.64     0.2985   36
# 981  0.94     0.2239   32
# 982  1.00     0.2985   25
# 983  1.00     0.2985   35
# 984  1.00     0.1343   42
# 985  1.00     0.2985   79
# 986  0.88     0.6119   80
# 987  0.88     0.6119   45
# 988  0.87     0.3881   80
# 989  0.93     0.4179   76
# 990  0.81     0.3881   45
# 991  0.70     0.4627    7
# 992  0.65     0.3881    4
# 993  0.69     0.2537    1
# 994  0.64     0.2836    2
# 995  0.59     0.2985   46
# 996  0.59     0.3284  107
# 997  0.59     0.3881  214
# 998  0.55     0.4179  124
# 999  0.52     0.2836   68
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Check if some values are entered incorrectly

# %%
print(train.loc[train['mnth'] == 0], '\n')
print(train.loc[train['season'] == 0], '\n')
# Out:
# Empty DataFrame
# Columns: [season, mnth, hr, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, cnt]
# Index: []
#
# Empty DataFrame
# Columns: [season, mnth, hr, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, cnt]
# Index: []

# %%
train.corr()
# Out:
#               season      mnth        hr   holiday   weekday  workingday  \
# season      1.000000  0.827196 -0.000419 -0.010078 -0.005052    0.015937
# mnth        0.827196  1.000000 -0.001590  0.021632  0.008748   -0.002201
# hr         -0.000419 -0.001590  1.000000  0.005858 -0.009208   -0.009144
# holiday    -0.010078  0.021632  0.005858  1.000000 -0.103690   -0.251099
# weekday    -0.005052  0.008748 -0.009208 -0.103690  1.000000    0.024178
# workingday  0.015937 -0.002201 -0.009144 -0.251099  0.024178    1.000000
# weathersit -0.009964  0.011915 -0.024430 -0.021671  0.000939    0.050495
# temp        0.311040  0.197312  0.141853 -0.024809 -0.002152    0.052084
# atemp       0.318805  0.203875  0.138453 -0.027825 -0.008360    0.051951
# hum         0.150011  0.163937 -0.278729 -0.012484 -0.039128    0.020971
# windspeed  -0.143865 -0.127921  0.136494  0.004177  0.009145   -0.007265
# cnt         0.177685  0.118684  0.394191 -0.029938  0.027766    0.020444
#
#             weathersit      temp     atemp       hum  windspeed       cnt
# season       -0.009964  0.311040  0.318805  0.150011  -0.143865  0.177685
# mnth          0.011915  0.197312  0.203875  0.163937  -0.127921  0.118684
# hr           -0.024430  0.141853  0.138453 -0.278729   0.136494  0.394191
# holiday      -0.021671 -0.024809 -0.027825 -0.012484   0.004177 -0.029938
# weekday       0.000939 -0.002152 -0.008360 -0.039128   0.009145  0.027766
# workingday    0.050495  0.052084  0.051951  0.020971  -0.007265  0.020444
# weathersit    1.000000 -0.095804 -0.098083  0.415143   0.031185 -0.142286
# temp         -0.095804  1.000000  0.987999 -0.075050  -0.016569  0.406540
# atemp        -0.098083  0.987999  1.000000 -0.057447  -0.055100  0.403033
# hum           0.415143 -0.075050 -0.057447  1.000000  -0.285831 -0.322821
# windspeed     0.031185 -0.016569 -0.055100 -0.285831   1.000000  0.093050
# cnt          -0.142286  0.406540  0.403033 -0.322821   0.093050  1.000000

# %%
train.groupby('mnth').cnt.sum().plot()
plt.show()

train.groupby('hr').cnt.sum().plot()
plt.show()

train.groupby('temp').cnt.sum().plot()
plt.show()

train.groupby('atemp').cnt.sum().plot()
plt.show()

# %% [markdown]
# ## Check for outliers

# %%
tempAndAtemp = train[['temp', 'atemp']]
tempAndAtemp.plot.scatter(x = 'temp', y = 'atemp')

windspeedAndAtemp = train[['windspeed', 'atemp']]
windspeedAndAtemp.plot.scatter(x = 'windspeed', y = 'atemp')

windspeedAndtemp = train[['windspeed', 'temp']]
windspeedAndtemp.plot.scatter(x = 'windspeed', y = 'temp')

windspeedAndhum = train[['windspeed', 'hum']]
windspeedAndhum.plot.scatter(x = 'windspeed', y = 'hum')

# %%
avgtempAndatemp = np.mean(train.temp - train.atemp)
print('Average temp to atemp difference:', avgtempAndatemp)

train.loc[abs(train.temp - train.atemp) >= 0.3, 'atemp'] = train.temp
# Out:
# Average temp to atemp difference: 0.02131903337169161

# %%
tempAndAtemp = train[['temp', 'atemp']]
tempAndAtemp.plot.scatter(x = 'temp', y = 'atemp')

windspeedAndAtemp = train[['windspeed', 'atemp']]
windspeedAndAtemp.plot.scatter(x = 'windspeed', y = 'atemp')

windspeedAndtemp = train[['windspeed', 'temp']]
windspeedAndtemp.plot.scatter(x = 'windspeed', y = 'temp')

windspeedAndhum = train[['windspeed', 'hum']]
windspeedAndhum.plot.scatter(x = 'windspeed', y = 'hum')

# %%
train_set, test_set = train_test_split(train, test_size = 0.3, random_state = 42)

x_train = train_set.drop('cnt', axis = 1)
y_train = train_set.cnt

x_test = test_set.drop('cnt', axis = 1)
y_test = test_set.cnt

# %%
'''rf_model = RandomForestRegressor(n_estimators = 1000, max_features=8, n_jobs = -1)

rf_model.fit(x_train, y_train)

y_pred = rf_model.predict(x_test)

print("Cross Validated Score:", np.mean(cross_val_score(rf_model, x_train, y_train, cv = 10)), '\n')
print(rf_model.feature_importances_)'''
# Out:
# 'rf_model = RandomForestRegressor(n_estimators = 1000, max_features=8, n_jobs = -1)\n\nrf_model.fit(x_train, y_train)\n\ny_pred = rf_model.predict(x_test)\n\nprint("Cross Validated Score:", np.mean(cross_val_score(rf_model, x_train, y_train, cv = 10)), \'\n\')\nprint(rf_model.feature_importances_)'

# %%
test.loc[test.temp - test.atemp >= 0.3, 'atemp'] = test.temp

# %%
'''full_set = train.copy()

x_full = full_set.drop('cnt', axis = 1)
y_full = full_set.cnt

rf_model.fit(x_full, y_full)

y_solution_predict = np.round(rf_model.predict(test))

print(y_solution_predict, '\n')

solution['cnt'] = y_solution_predict

solution['cnt'] = solution['cnt'].astype('int')

solution_full = test.copy();

solution_full['cnt'] = y_solution_predict

solution_full['cnt'] = solution_full['cnt'].astype('int')'''
# Out:
# "full_set = train.copy()\n\nx_full = full_set.drop('cnt', axis = 1)\ny_full = full_set.cnt\n\nrf_model.fit(x_full, y_full)\n\ny_solution_predict = np.round(rf_model.predict(test))\n\nprint(y_solution_predict, '\n')\n\nsolution['cnt'] = y_solution_predict\n\nsolution['cnt'] = solution['cnt'].astype('int')\n\nsolution_full = test.copy();\n\nsolution_full['cnt'] = y_solution_predict\n\nsolution_full['cnt'] = solution_full['cnt'].astype('int')"

# %%
solution_full.groupby('mnth').cnt.sum().plot()
plt.show()

solution_full.groupby('hr').cnt.sum().plot()
plt.show()

tempAndAtemp = solution_full[['temp', 'atemp']]
tempAndAtemp.plot.scatter(x = 'temp', y = 'atemp')

tempAndAtemp = solution_full[['windspeed', 'atemp']]
tempAndAtemp.plot.scatter(x = 'windspeed', y = 'atemp')

solution_full.head()
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       4    10   3        0        2           1           1  0.44  0.4394
# 1       1     2   9        0        3           1           1  0.18  0.2121
# 2       2     3  12        0        6           0           1  0.30  0.2879
# 3       4    10   3        0        0           0           2  0.44  0.4394
# 4       1     3  21        0        3           1           1  0.34  0.2879
#
#     hum  windspeed  cnt
# 0  0.94     0.0896    8
# 1  0.51     0.0896  193
# 2  0.36     0.1940  243
# 3  0.62     0.1343   34
# 4  0.29     0.4627  101

# %%
#solution.to_csv('data/solution.csv', index = False )

# %%
estimators = np.arange(1, 100, 1)
scores = []

best_n = 1080
best_score = 0.8565935831960831

model = RandomForestRegressor(n_estimators = 10, random_state = 42, n_jobs = -1)

for n in estimators:
    model.set_params(n_estimators=n)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    score = model.score(x_test, y_test)
    scores.append(score)
    
    if score > best_score:
        print('New Best is n =', n)
        best_n = n
        best_score = score

plt.title("Effect of n_estimators")
plt.xlabel("n_estimator")
plt.ylabel("Score")
plt.plot(estimators, scores)

print("Best n is:", best_n)
print("Best n is:", best_score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-747d5d3f3e14> in <module>
#       9 for n in estimators:
#      10     model.set_params(n_estimators=n)
# ---> 11     model.fit(x_train, y_train)
#      12     y_pred = model.predict(x_test)
#      13     score = model.score(x_test, y_test)
#
# F:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     331                     t, self, X, y, sample_weight, i, len(trees),
#     332                     verbose=self.verbose, class_weight=self.class_weight)
# --> 333                 for i, t in enumerate(trees))
#     334
#     335             # Collect newly grown trees
#
# F:\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# F:\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# F:\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# F:\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# F:\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# F:\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
full_set = train.copy()

x_full = full_set.drop('cnt', axis = 1)
y_full = full_set.cnt

model = RandomForestRegressor(n_estimators = 1080, random_state = 42, n_jobs = -1)
model.fit(x_full, y_full)

y_solution_predict = model.predict(test)

y_solution_predict_pd = pd.DataFrame(y_solution_predict)

print(y_solution_predict, '\n')

solution['cnt'] = np.round(y_solution_predict_pd.clip(lower = 0))

solution['cnt'] = solution['cnt'].astype('int')

solution_full = test.copy();

solution_full['cnt'] = solution['cnt']

solution_full['cnt'] = solution_full['cnt'].astype('int')

solution.to_csv('data/solution.csv', index = False)
solution.head(20)
# Out:
# [  4.11111111 196.40555556 175.02685185 ...   7.6537037  130.47314815
#  414.43611111]
#     Id  cnt
# 0    1    4
# 1    2  196
# 2    3  175
# 3    4   40
# 4    5  111
# 5    6  120
# 6    7   77
# 7    8  141
# 8    9  111
# 9   10  364
# 10  11    5
# 11  12  227
# 12  13   35
# 13  14  256
# 14  15   47
# 15  16  200
# 16  17   10
# 17  18   64
# 18  19   37
# 19  20  140

# %%
estimators = np.arange(2000, 5000, 100)
scores = []

best_n = 0
best_score = 0.863266393951517

model = XGBRegressor(n_estimators = 1000, early_stopping_rounds=10, learning_rate = 0.2, seed = 42)

for n in estimators:
    model.set_params(n_estimators=n)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    score = model.score(x_test, y_test)
    scores.append(score)
    
    if score > best_score:
        print('New Best is n =', n)
        best_n = n
        best_score = score

plt.title("Effect of n_estimators")
plt.xlabel("n_estimator")
plt.ylabel("Score")
plt.plot(estimators, scores)

print("Best n is:", best_n)
print("Best n is:", best_score)
# Out:
# New Best is n = 2000
# New Best is n = 2200
# New Best is n = 2300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-36d925b59afc> in <module>
#      10     model.set_params(n_estimators=n)
#      11     model.fit(x_train, y_train)
# ---> 12     y_pred = model.predict(x_test)
#      13     score = model.score(x_test, y_test)
#      14     scores.append(score)
#
# F:\Anaconda3\lib\site-packages\xgboost\sklearn.py in predict(self, data, output_margin, ntree_limit)
#     382         return self.get_booster().predict(test_dmatrix,
#     383                                           output_margin=output_margin,
# --> 384                                           ntree_limit=ntree_limit)
#     385
#     386     def apply(self, X, ntree_limit=0):
#
# F:\Anaconda3\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features)
#    1200                                           ctypes.c_uint(ntree_limit),
#    1201                                           ctypes.byref(length),
# -> 1202                                           ctypes.byref(preds)))
#    1203         preds = ctypes2numpy(preds, length.value, np.float32)
#    1204         if pred_leaf:
#
# KeyboardInterrupt:

# %%
full_set = train.copy()

x_full = full_set.drop('cnt', axis = 1)
y_full = full_set.cnt

xg_model = XGBRegressor(n_estimators = 1000, early_stopping_rounds=10, learning_rate = 0.2)
xg_model.fit(x_full, y_full)

y_solution_predict = xg_model.predict(test)

y_solution_predict_pd = pd.DataFrame(y_solution_predict)

print(y_solution_predict, '\n')

solution['cnt'] = np.round(y_solution_predict_pd.clip(lower = 0))

solution['cnt'] = solution['cnt'].astype('int')

solution_full = test.copy();

solution_full['cnt'] = solution['cnt']

solution_full['cnt'] = solution_full['cnt'].astype('int')

solution.head(20)
# Out:
# [  4.697143 201.32376  228.74503  ...  12.075238 137.24173  478.14365 ]
#     Id  cnt
# 0    1    5
# 1    2  201
# 2    3  229
# 3    4   27
# 4    5   79
# 5    6   10
# 6    7   93
# 7    8  131
# 8    9   96
# 9   10  404
# 10  11    0
# 11  12  240
# 12  13   62
# 13  14  304
# 14  15    0
# 15  16  140
# 16  17   12
# 17  18   89
# 18  19   14
# 19  20  140

# %%
solution.head()

solution.to_csv('data/solution.csv', index = False)
